# %% [markdown]
# <a href="https://colab.research.google.com/github/prateekk21/ipl-t20-cricket-analysis/blob/main/Team_Notebook_IPL_T20_Cricket_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **<ins>Exploratory Data Analysis of IPL T20 Dataset from 2008 to 2019</ins>**
# "*The IPL has taken the game to virtually every house in the world.*"
# --Sachin Tendulkar
#
# *(Source: https://www.espncricinfo.com/magazine/content/quote/350779.html)*

# %% [markdown]
# ![ipl-captains-hd.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ##<b><ins>What is IPL?</ins>
# ###The Indian Premier League is a professional Twenty20 cricket league in India usually contested between March and May of every year by eight teams representing eight different cities or states in India. The league was founded by the Board of Control for Cricket in India in 2007. The IPL has an exclusive window in ICC Future Tours Programme.
#
# ###The IPL is the most-attended cricket league in the world and in 2014 was ranked sixth by average attendance among all sports leagues. In 2010, the IPL became the first sporting event in the world to be broadcast live on YouTube. The brand value of the IPL in 2019 was ₹475 billion (US$6.7 billion), according to Duff & Phelps. According to BCCI, the 2015 IPL season contributed ₹11.5 billion to the GDP of the Indian economy.
# *(Source: https://en.wikipedia.org/wiki/Indian_Premier_League)*

# %% [markdown]
# ##**<ins>How is IPL played?</ins>**
#
# ###There are a total of eight teams, each team plays with another team twice. In these two matches, one is played on the home ground of one team and other is played on another team's home ground. With eight teams, the total number of matches played is 56, though this number can change incase of ties or increase in the number of teams. Two points allocated for a winning team. The top four teamsz who have maximum points qualify for the playoffs.
#
# ###In the playoffs, the top two teams will play against each other to qualify for the final. Bottom two teams will play against each other and the loser of this match will be eliminated from the tournament. Now, the loser of top teams and winner of the bottom two teams will play against each other and that decides the second finalist of IPL.
#
# ###Finally the finalists play against each other to win the IPL trophy and prize money as much as 10 crores.

# %% [markdown]
# #<ins>Let's take a look at the problem statement</ins>

# %% [markdown]
# ## Indian Premier League(IPL) is a professional Twenty20 cricket league in India contested during March or April and May of every year by eight teams representing eight different cities in India. The league was founded by the Board of Control for Cricket in India(BCCI) in 2008.
#
# ## Explore and analyze the data to discover results and statistics for different teams playing in IPL.

# %% [markdown]
# #Now lets start exploring the project
#
#
# #<ins> The dataset consists of the following:</ins>
#
#
# *   Players Data
# *   Deliveries Data
# *   Matches Data
# *   Average Strikerate Data
# *   Teamwise Home and Away Data

# %% [markdown]
# #<ins> Objectives:</ins>
#
# *   To find the number of seasons in this dataset.
# *   To find the number of matches in this dataset.
# *   To check how many players are left handed and right handed.
# *   To plot players as per their bowling skills.
# *   To plot players as per their respective country.
# *   To find top scorer batsmen.
# *   To find which team won by maximum runs.
# *   To find which team won by minimum runs.
# *   To find which team won by maximum wickets.
# *   To find which team won by minimum wickets.
# *   To find top toss winners from all seasons.
# *   To find the number of matches per season.
# *   To find if toss winning helped in match winning.
# *   To find the top 5 venues used for matches.
# *   To find the top 5 cities where the maximum maches were held.
# *   To find top 5 teams which won maximum number of times in all seasons.
# *   To find top 5 teams which has maximum home matches.
# *   To find top 5 batsman who scored maximum sixes.
# *   To find top 5 batsman who scored maximum fours.
# *   To find top 5 players who got man of the match.
# *   To find which team won the toss maximum times
# *   To find the performance report of the top 3 teams
# *   To find the Age group of players as of in 2020.
# *   To find the Venue, Team and Win relation.
# *   To find the most common way of dismissal
# *   To find dismissal records of players who scored maximum runs

# %% [markdown]
# # <ins>Let's begin with importing required libraries</ins>
#
# * Pandas
# * Numpy
# * Seaborn
# * Pyplot

# %%
from collections import Counter
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# #<ins>So, here we are importing all the csv and xlsx files to start the analysis.</ins>

# %%
dir =  '/content/drive/MyDrive/AlmaBetter/Month 1/EDA/'

# %%
players_df = pd.read_excel(dir + 'Players.xlsx')
deliveries_df = pd.read_csv(dir + 'deliveries.csv')
matches_df = pd.read_csv(dir+'matches.csv')
most_runs_df = pd.read_csv(dir+'most_runs_average_strikerate.csv')
teams_df = pd.read_csv(dir+'teams.csv')
teamwise_home_away_df = pd.read_csv(dir+'teamwise_home_and_away.csv')

# %% [markdown]
# ## Players Dataframe

# %%
players_df.head()
# Out:
#       Player_Name        DOB Batting_Hand         Bowling_Skill Country
# 0  A Ashish Reddy 1991-02-24   Right_Hand      Right-arm medium   India
# 1      A Chandila 1983-12-05   Right_Hand    Right-arm offbreak   India
# 2        A Chopra 1977-09-19   Right_Hand    Right-arm offbreak   India
# 3     A Choudhary        NaT   Right_hand  Left-arm fast-medium     NaN
# 4     A Dananjaya        NaT   Right_Hand    Right-arm offbreak     NaN

# %%
players_df.tail()
# Out:
#       Player_Name        DOB Batting_Hand           Bowling_Skill   Country
# 561   Younis Khan 1977-11-29   Right_Hand        Right-arm medium  Pakistan
# 562     YS Chahal 1990-07-23   Right_Hand         Legbreak googly     India
# 563  Yuvraj Singh 1981-12-12    Left_Hand  Slow left-arm orthodox     India
# 564   YV Takawale 1984-11-05   Right_Hand                     NaN     India
# 565        Z Khan 1978-10-07   Right_Hand    Left-arm fast-medium     India

# %%
players_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 566 entries, 0 to 565
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Player_Name    566 non-null    object
#  1   DOB            471 non-null    datetime64[ns]
#  2   Batting_Hand   563 non-null    object
#  3   Bowling_Skill  502 non-null    object
#  4   Country        471 non-null    object
# dtypes: datetime64[ns](1), object(4)
# memory usage: 22.2+ KB

# %%
players_df.shape
# Out:
# (566, 5)

# %% [markdown]
# ###In this dataframe, Player details are given:
#
# *   Player_Name: Name of the player.
# *   DOB: Date Of Birth of the player
# *   Batting_Hand: Hand which is used by the player while batting.
# *   Bowling_Skill: Type of skill the player possess.
# *   Country: Shows the name of country to which the player belongs.

# %% [markdown]
# ## Deliveries Dataframe

# %%
deliveries_df.head()
# Out:
#    match_id  inning  ... dismissal_kind fielder
# 0         1       1  ...            NaN     NaN
# 1         1       1  ...            NaN     NaN
# 2         1       1  ...            NaN     NaN
# 3         1       1  ...            NaN     NaN
# 4         1       1  ...            NaN     NaN
#
# [5 rows x 21 columns]

# %%
deliveries_df.tail()
# Out:
#         match_id  inning  ... dismissal_kind    fielder
# 179073     11415       2  ...            NaN        NaN
# 179074     11415       2  ...            NaN        NaN
# 179075     11415       2  ...        run out  KH Pandya
# 179076     11415       2  ...            NaN        NaN
# 179077     11415       2  ...            lbw        NaN
#
# [5 rows x 21 columns]

# %%
deliveries_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 179078 entries, 0 to 179077
# Data columns (total 21 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   match_id          179078 non-null  int64
#  1   inning            179078 non-null  int64
#  2   batting_team      179078 non-null  object
#  3   bowling_team      179078 non-null  object
#  4   over              179078 non-null  int64
#  5   ball              179078 non-null  int64
#  6   batsman           179078 non-null  object
#  7   non_striker       179078 non-null  object
#  8   bowler            179078 non-null  object
#  9   is_super_over     179078 non-null  int64
#  10  wide_runs         179078 non-null  int64
#  11  bye_runs          179078 non-null  int64
#  12  legbye_runs       179078 non-null  int64
#  13  noball_runs       179078 non-null  int64
#  14  penalty_runs      179078 non-null  int64
#  15  batsman_runs      179078 non-null  int64
# ...

# %%
deliveries_df.shape
# Out:
# (179078, 21)

# %% [markdown]
# ###In this dataframe, Each delivery details are given for each match:
#
# *   match_id: Each match has a specific id.
# *   inning: Shows the innings (First or Second)
# *   batting_team: Team which is currently batting.
# *   bowling_team: Team which is currently bowling.
# *   over: Shows the over number.
# *   ball: Ball number
# *   batsman: Batsman Name
# *   non_striker: Non-striker name
# *   bowler: Bowler name
# *   is_super_over: Shows if it is a super over
# *   wide_runs: Runs by wide ball
# *   bye_runs: bye runs
# *   legbye_runs: Leg bye runs
# *   noball_runs: Runs scored on noball
# *   penalty_runs: Runs scored in penalty
# *   batsman_runs: Runs scored by the batsman
# *   extra_runs: Extra runs scored.
# *   total_runs: sum of all the runs on a single ball
# *   player_dismissed: Player name who got out.
# *   dismissal_kind: How did that player got out.
# *   fielder: Name of fielder who got the catch

# %% [markdown]
# ## Matches Dataframe

# %%
matches_df.head()
# Out:
#    id    Season       city  ...         umpire1        umpire2 umpire3
# 0   1  IPL-2017  Hyderabad  ...     AY Dandekar       NJ Llong     NaN
# 1   2  IPL-2017       Pune  ...  A Nand Kishore         S Ravi     NaN
# 2   3  IPL-2017     Rajkot  ...     Nitin Menon      CK Nandan     NaN
# 3   4  IPL-2017     Indore  ...    AK Chaudhary  C Shamshuddin     NaN
# 4   5  IPL-2017  Bangalore  ...             NaN            NaN     NaN
#
# [5 rows x 18 columns]

# %%
matches_df.tail()
# Out:
#         id    Season  ...         umpire2                  umpire3
# 751  11347  IPL-2019  ...        O Nandan                   S Ravi
# 752  11412  IPL-2019  ...     Nitin Menon                Ian Gould
# 753  11413  IPL-2019  ...             NaN                      NaN
# 754  11414  IPL-2019  ...  Bruce Oxenford  Chettithody Shamshuddin
# 755  11415  IPL-2019  ...       Ian Gould              Nigel Llong
#
# [5 rows x 18 columns]

# %%
matches_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 756 entries, 0 to 755
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               756 non-null    int64
#  1   Season           756 non-null    object
#  2   city             749 non-null    object
#  3   date             756 non-null    object
#  4   team1            756 non-null    object
#  5   team2            756 non-null    object
#  6   toss_winner      756 non-null    object
#  7   toss_decision    756 non-null    object
#  8   result           756 non-null    object
#  9   dl_applied       756 non-null    int64
#  10  winner           752 non-null    object
#  11  win_by_runs      756 non-null    int64
#  12  win_by_wickets   756 non-null    int64
#  13  player_of_match  752 non-null    object
#  14  venue            756 non-null    object
#  15  umpire1          754 non-null    object
#  16  umpire2          754 non-null    object
# ...

# %%
matches_df['dl_applied'].unique()
# Out:
# array([0, 1])

# %%
matches_df.shape
# Out:
# (756, 18)

# %% [markdown]
# ###In this dataframe, Each match details are given:
#
# *   id: Each match has a specific id.
# *   Season: Shows the Season name
# *   city: shows the city in which the match was held.
# *   date: date of match
# *   team1: First Team.
# *   team2: Second Team
# *   toss_winner: Shows the team which won the toss.
# *   toss_decision: Decision made by toss winning team.
# *   result: Shows if it was a tie or normal match
# *   dl_applied: Duckworth–Lewis–Stern method was applied or not
# *   winner: Name of the winning team
# *   win_by_runs: Won by how much runs
# *   win_by_wickets: won by how much wickets
# *   player_of_match: Name of the player who got player of the match
# *   venue: Name of the venue.
# *   umpire1: Name of umpire1
# *   umpire2: Name of umpire2
# *   umpire3: Name of umpire3

# %% [markdown]
# ## Most runs average strikerate Dataframe

# %%
most_runs_df.head()
# Out:
#      batsman  total_runs  out  numberofballs    average  strikerate
# 0    V Kohli        5426  152           4111  35.697368  131.987351
# 1   SK Raina        5386  160           3916  33.662500  137.538304
# 2  RG Sharma        4902  161           3742  30.447205  130.999466
# 3  DA Warner        4717  114           3292  41.377193  143.286756
# 4   S Dhawan        4601  137           3665  33.583942  125.538881

# %%
most_runs_df.tail()
# Out:
#             batsman  total_runs  out  numberofballs  average  strikerate
# 511        ND Doshi           0    1             13      0.0         0.0
# 512         J Denly           0    1              1      0.0         0.0
# 513         S Ladda           0    2              9      0.0         0.0
# 514  V Pratap Singh           0    1              1      0.0         0.0
# 515       S Kaushik           0    1              1      0.0         0.0

# %%
most_runs_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 516 entries, 0 to 515
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   batsman        516 non-null    object
#  1   total_runs     516 non-null    int64
#  2   out            516 non-null    int64
#  3   numberofballs  516 non-null    int64
#  4   average        482 non-null    float64
#  5   strikerate     516 non-null    float64
# dtypes: float64(2), int64(3), object(1)
# memory usage: 24.3+ KB

# %%
most_runs_df.shape
# Out:
# (516, 6)

# %% [markdown]
# ###In this dataframe, Each player details are given:
#
# *   batsman: Name of the batsman
# *   total_runs: Total runs made by the batsman
# *   out: No. of times the batsman got out.
# *   numberofballs: Number of balls played by him.
# *   average: average of the perticular batsman
# *   strikerate: Strikerate of the batsman

# %% [markdown]
# ## Teams Dataframe

# %%
teams_df.head()
# Out:
#                    team1
# 0          Pune Warriors
# 1  Kolkata Knight Riders
# 2       Rajasthan Royals
# 3   Kochi Tuskers Kerala
# 4          Gujarat Lions

# %%
teams_df.tail()
# Out:
#                           team1
# 10               Mumbai Indians
# 11          Sunrisers Hyderabad
# 12       Rising Pune Supergiant
# 13  Royal Challengers Bangalore
# 14              Kings XI Punjab

# %%
teams_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   team1   15 non-null     object
# dtypes: object(1)
# memory usage: 248.0+ bytes

# %%
teams_df.shape
# Out:
# (15, 1)

# %% [markdown]
# ###In this dataframe, team names are given
#
# *   team1: Name of team

# %% [markdown]
# ## Teamwise home and away Dataframe

# %%
teamwise_home_away_df.head()
# Out:
#                      team  home_wins  ...  home_win_percentage  away_win_percentage
# 0  Rising Pune Supergiant          5  ...            62.500000            62.500000
# 1          Mumbai Indians         58  ...            57.425743            59.302326
# 2     Chennai Super Kings         51  ...            57.303371            65.333333
# 3          Delhi Capitals          3  ...            50.000000            70.000000
# 4     Sunrisers Hyderabad         30  ...            47.619048            62.222222
#
# [5 rows x 7 columns]

# %%
teamwise_home_away_df.tail()
# Out:
#                      team  home_wins  ...  home_win_percentage  away_win_percentage
# 9   Kolkata Knight Riders         34  ...            40.963855            61.052632
# 10       Delhi Daredevils         25  ...            34.722222            47.191011
# 11          Pune Warriors          6  ...            30.000000            23.076923
# 12   Kochi Tuskers Kerala          2  ...            28.571429            57.142857
# 13          Gujarat Lions          1  ...             7.142857            75.000000
#
# [5 rows x 7 columns]

# %%
teamwise_home_away_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14 entries, 0 to 13
# Data columns (total 7 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   team                 14 non-null     object
#  1   home_wins            14 non-null     int64
#  2   away_wins            14 non-null     int64
#  3   home_matches         14 non-null     int64
#  4   away_matches         14 non-null     int64
#  5   home_win_percentage  14 non-null     float64
#  6   away_win_percentage  14 non-null     float64
# dtypes: float64(2), int64(4), object(1)
# memory usage: 912.0+ bytes

# %%
teamwise_home_away_df.shape
# Out:
# (14, 7)

# %% [markdown]
# ###In this dataframe, Each team details are given:
#
# *   team: Name of team
# *   home_wins: No. of times the team won in its own city.
# *   away_wins: No. of times team won in other city.
# *   home_matches: No. of matches played in own city
# *   away_matches: No. of matches played in other city
# *   home_win_percentage: Percentage of matches won in own city
# *   away_win_percentage: Percentage of matches won in other city

# %% [markdown]
# # <ins>Matches we have in this dataset</ins>

# %%
matches_df.head()
# Out:
#    id    Season       city  ...         umpire1        umpire2 umpire3
# 0   1  IPL-2017  Hyderabad  ...     AY Dandekar       NJ Llong     NaN
# 1   2  IPL-2017       Pune  ...  A Nand Kishore         S Ravi     NaN
# 2   3  IPL-2017     Rajkot  ...     Nitin Menon      CK Nandan     NaN
# 3   4  IPL-2017     Indore  ...    AK Chaudhary  C Shamshuddin     NaN
# 4   5  IPL-2017  Bangalore  ...             NaN            NaN     NaN
#
# [5 rows x 18 columns]

# %%
len(matches_df['id'])
# Out:
# 756

# %% [markdown]
# ##Observation: We have 756 matches in this dataset

# %% [markdown]
# # <ins>Seasons we have in this dataset</ins>

# %%
matches_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 756 entries, 0 to 755
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               756 non-null    int64
#  1   Season           756 non-null    object
#  2   city             749 non-null    object
#  3   date             756 non-null    object
#  4   team1            756 non-null    object
#  5   team2            756 non-null    object
#  6   toss_winner      756 non-null    object
#  7   toss_decision    756 non-null    object
#  8   result           756 non-null    object
#  9   dl_applied       756 non-null    int64
#  10  winner           752 non-null    object
#  11  win_by_runs      756 non-null    int64
#  12  win_by_wickets   756 non-null    int64
#  13  player_of_match  752 non-null    object
#  14  venue            756 non-null    object
#  15  umpire1          754 non-null    object
#  16  umpire2          754 non-null    object
# ...

# %%
len(matches_df['Season'].unique())
# Out:
# 12

# %% [markdown]
# ##Observation: There are 12 seasons in this dataset. 2008 to 2019

# %% [markdown]
# #<ins>Number of matches per season</ins>

# %% [markdown]
# ### We will use the value_counts method to print the number of matches per season

# %%
matches_df['Season'].value_counts().reset_index()
# Out:
#        index  Season
# 0   IPL-2013      76
# 1   IPL-2012      74
# 2   IPL-2011      73
# 3   IPL-2014      60
# 4   IPL-2016      60
# 5   IPL-2010      60
# 6   IPL-2018      60
# 7   IPL-2019      60
# 8   IPL-2015      59
# 9   IPL-2017      59
# 10  IPL-2008      58
# 11  IPL-2009      57

# %% [markdown]
# ### Here, we will insert a new column named 'Season_year' which will fetch the year from Season column.

# %%
matches_df['Season_year'] = matches_df['Season'].apply(lambda x: x[-4:])

# %%
matches_df_2 = matches_df['Season_year'].value_counts().reset_index()

# %%
matches_df_2.sort_values(by=['index'])
# Out:
#    index  Season_year
# 10  2008           58
# 11  2009           57
# 3   2010           60
# 2   2011           73
# 1   2012           74
# 0   2013           76
# 4   2014           60
# 8   2015           59
# 5   2016           60
# 9   2017           59
# 7   2018           60
# 6   2019           60

# %%
plt.figure(figsize=(25,9))
plt.xticks(
    rotation=45, 
    horizontalalignment='right',
    fontweight='light',
    fontsize='x-large'  
)
sns.barplot('index', 'Season_year', data=matches_df_2.sort_values(by=['index']))
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
matches_df_2.sort_values(by=['index']).plot(x = 'index', y='Season_year', grid = True, figsize = (15,7))

# %% [markdown]
# ##Observation: In 2013, we had maximum number of matches.

# %% [markdown]
# # <ins>Let's check maximum players are from which country</ins>

# %%
player_country = players_df['Country'].value_counts().reset_index()
player_country.rename(columns={'index': 'Country', 'Country':'No. of players'}, inplace=True)

# %% [markdown]
# ### Let's plot the above information on graph

# %%
plt.figure(figsize=(15,9))
plt.xticks(
    rotation=45, 
    horizontalalignment='right',
    fontweight='light',
    fontsize='x-large'  
)
sns.barplot('Country', 'No. of players', data=player_country)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
plot = player_country.plot.pie(y='No. of players',labels=player_country.Country, figsize=(12,1))

# %% [markdown]
# ##Observation: Maximum players are from india which is pretty obvious.

# %% [markdown]
# ##Let's print the deliveries dataframe for further anaysis.

# %%
deliveries_df.head()
# Out:
#    match_id  inning  ... dismissal_kind fielder
# 0         1       1  ...            NaN     NaN
# 1         1       1  ...            NaN     NaN
# 2         1       1  ...            NaN     NaN
# 3         1       1  ...            NaN     NaN
# 4         1       1  ...            NaN     NaN
#
# [5 rows x 21 columns]

# %% [markdown]
# # <ins>Let's plot the Players and their batting hand</ins>
#
# Batsman are very crucial and the runs scored by them or runs chased can be huge contributers to the win and loss of match.
#
# Batsman can be of two types. Right hand batsman and left Hand batsman.
# Which are the most? Lets find out.

# %%
# creating a data frame that has counts of batting hand and players
players_df.replace(to_replace='Right_hand', value='Right_Hand',inplace=True) # this step helps us avoid mistake in data interpretaion due to different spelling of same object
Hand_of_players = pd.DataFrame(players_df['Batting_Hand'].value_counts()) # taking values and converting to df
Hand_of_players = Hand_of_players.reset_index() # resetting the index
Hand_of_players.columns = ['Batting_hand', 'Number_of_players'] # renaming columns
Hand_of_players
# Out:
#   Batting_hand  Number_of_players
# 0   Right_Hand                421
# 1    Left_Hand                142

# %%
#visualizing data

plt.figure(figsize=(10, 10)) # setting size of plot
plt.title('Percentage of Right handed batsman v/s Left handed batsman')
ax = sns.barplot(x="Batting_hand", y='Number_of_players', data=Hand_of_players) # bar plot with hand as x axis and number of players as y
total = 421+142
for p in ax.patches:
    width = p.get_width()
    height = p.get_height()
    per = height *100 / total
    x, y = p.get_xy() 
    ax.annotate(f'{per:.2f} %', (x + width/2, y + height*1.02), ha='center')

# %% [markdown]
# ##Observation: 74.78% of batsmen are Right Handed and 25.22% of batsmen are Left Handed.

# %% [markdown]
# # <ins>Let's try to plot the graph of bowling skills.</ins>
# Unlike batsman which are right handed or left handed bowlers can be of different.
#
# * Fast bowler
# * medium fast bowlers
# * off spinners
# * leg spinners
#
# and also based ontheir hand of choice

# %%
players_df['Bowling_Skill'].value_counts().reset_index()
# Out:
#                      index  Bowling_Skill
# 0         Right-arm medium            107
# 1       Right-arm offbreak             91
# 2    Right-arm fast-medium             68
# 3   Slow left-arm orthodox             50
# 4           Right-arm fast             39
# 5    Right-arm medium-fast             38
# 6                 Legbreak             30
# 7          Legbreak googly             28
# 8     Left-arm fast-medium             19
# 9          Left-arm medium             11
# 10    Left-arm medium-fast              9
# 11  Slow left-arm chinaman              5
# 12           Left-arm fast              4
# 13          Right-arm Fast              1
# 14        Right-arm bowler              1
# 15        Right-arm Medium              1

# %% [markdown]
# ### Let's plot the above information in a graphical manner.

# %%
plt.figure(figsize=(30,9))
plt.xticks(
    rotation=45, 
    horizontalalignment='right',
    fontweight='light',
    fontsize='x-large'  
)
sns.barplot('index', 'Bowling_Skill', data=players_df['Bowling_Skill'].value_counts().reset_index())
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# ##Observation: Maximum number of players have Right-arm medium skill

# %% [markdown]
# #<ins>Age group of players as of in 2020</ins>
#
# Fitness and age determine a players performance. A team like CSK where average age of players was 30 in 2019. Age bring problems with fitness and aged people are prone to injuries. But age also brings Experience that can also be a reason for CSK to win So many times.
#
# Let us find out how many players fall in which category.

# %%
Age_of_players = pd.DataFrame(players_df['DOB'].dt.year.value_counts()) # taking values and converting to df
Age_of_players = Age_of_players.reset_index() # resetting the index
Age_of_players.columns = ['Year_of_Birth', 'Number_of_players'] # renaming columns
Age_of_players['Age'] = 2020 - Age_of_players['Year_of_Birth']
Age_of_players
# Out:
#     Year_of_Birth  Number_of_players   Age
# 0          1984.0                 41  36.0
# 1          1990.0                 33  30.0
# 2          1981.0                 32  39.0
# 3          1983.0                 32  37.0
# 4          1987.0                 31  33.0
# 5          1985.0                 31  35.0
# 6          1988.0                 30  32.0
# 7          1989.0                 26  31.0
# 8          1986.0                 24  34.0
# 9          1982.0                 23  38.0
# 10         1991.0                 19  29.0
# 11         1980.0                 17  40.0
# 12         1993.0                 16  27.0
# 13         1979.0                 16  41.0
# 14         1977.0                 15  43.0
# 15         1992.0                 11  28.0
# 16         1974.0                 11  46.0
# 17         1978.0                 11  42.0
# 18         1975.0                 10  45.0
# 19         1976.0                  9  44.0
# 20         1994.0                  9  26.0
# ...

# %%
#visualizing data

plt.figure(figsize=(25, 10)) # setting size of plot
plt.title('Percentage of Age')
ax = sns.barplot(x="Age", y='Number_of_players', data = Age_of_players) # bar plot with hand as x axis and number of players as y
total = 421+142
for p in ax.patches:
    width = p.get_width()
    height = p.get_height()
    per = height *100 / total
    x, y = p.get_xy() 
    ax.annotate(f'{per:.2f} %', (x + width/2, y + height*1.02), ha='center')

# %% [markdown]
# Observation: From data we see that maximum players are  between 27 to 41 years of age.

# %% [markdown]
# # <ins>Now, we will check which player had scored maximum runs in all matches.</ins>

# %% [markdown]
# ### Here we will apply the groupby method to sum up all the scores for each batsman

# %%
deliveries_df_1 = deliveries_df.groupby('batsman').agg({'batsman_runs': sum}).reset_index()

# %%
deliveries_df_1.sort_values(by=['batsman_runs'], ascending=False, inplace=True)

# %%
plt.figure(figsize=(30,9))
plt.xticks(
    rotation=45, 
    horizontalalignment='right',
    fontweight='light',
    fontsize='x-large'  
)
sns.barplot('batsman', 'batsman_runs', data=deliveries_df_1.head(10))
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# ##Observation: Virat Kohli is the highest scorer batsman.

# %% [markdown]
# # <ins>Let's check which team won by maximum runs</ins>

# %%
matches_df1 = matches_df.sort_values(by=['win_by_runs'], ascending = False).reset_index()

# %% [markdown]
# ### We can use the sort_values method to sort the 'win by runs' column in descending manner to get the maximum runs.

# %%
matches_df1.head()
# Out:
#    index   id    Season  ...        umpire2 umpire3 Season_year
# 0     43   44  IPL-2017  ...      CK Nandan     NaN        2017
# 1    619  620  IPL-2016  ...      VK Sharma     NaN        2016
# 2     59   60  IPL-2008  ...    RE Koertzen     NaN        2008
# 3    556  557  IPL-2015  ...    VA Kulkarni     NaN        2015
# 4    410  411  IPL-2013  ...  C Shamshuddin     NaN        2013
#
# [5 rows x 20 columns]

# %%
matches_df1['winner'][matches_df['win_by_runs'].idxmax()]
# Out:
# 'Mumbai Indians'

# %% [markdown]
# ## Observation: Mumbai Indians has won by maximum runs

# %% [markdown]
# #<ins>Let's check which team won by minimum runs margin</ins>

# %% [markdown]
# ### We can use the idxmax method to fetch the max index from the specific column.

# %%
matches_df3 = matches_df[matches_df['win_by_runs']==1]
matches_df3['winner'][matches_df3['win_by_runs'].idxmax()]
# Out:
# 'Mumbai Indians'

# %% [markdown]
# ## Observation: Mumbai Indians has won by minimum runs

# %% [markdown]
# # <ins>Let's check which team won by maximum wickets</ins>

# %%
matches_df2 = matches_df.sort_values(by=['win_by_wickets'], ascending = False).reset_index()

# %%
matches_df['winner'][matches_df['win_by_wickets'].idxmax()]
# Out:
# 'Kolkata Knight Riders'

# %% [markdown]
# ## Observation: Kolkata Knight Riders has won by maximum wickets

# %% [markdown]
# # <ins>Which team won by min wickets</ins>

# %%
matches_df4 = matches_df[matches_df['win_by_wickets']==1]
matches_df4['winner'][matches_df4['win_by_wickets'].idxmax()]
# Out:
# 'Kolkata Knight Riders'

# %% [markdown]
# ## Observation: Kolkata Knight Riders has won by minimum wickets

# %% [markdown]
# # <ins>Let's find out whether toss winning helped the team in winning the match.</ins>

# %%
matches_df.head()
# Out:
#    id    Season       city  ...        umpire2 umpire3 Season_year
# 0   1  IPL-2017  Hyderabad  ...       NJ Llong     NaN        2017
# 1   2  IPL-2017       Pune  ...         S Ravi     NaN        2017
# 2   3  IPL-2017     Rajkot  ...      CK Nandan     NaN        2017
# 3   4  IPL-2017     Indore  ...  C Shamshuddin     NaN        2017
# 4   5  IPL-2017  Bangalore  ...            NaN     NaN        2017
#
# [5 rows x 19 columns]

# %% [markdown]
# ###We will create a new column which will have boolean values. True if the team won the match after winning toss and False if Team lost the match after winning the toss.

# %%
matches_df['won_after_winning_toss'] = matches_df['toss_winner']==matches_df['winner']

# %%
matches_df.head()
# Out:
#    id    Season       city  ... umpire3 Season_year won_after_winning_toss
# 0   1  IPL-2017  Hyderabad  ...     NaN        2017                  False
# 1   2  IPL-2017       Pune  ...     NaN        2017                   True
# 2   3  IPL-2017     Rajkot  ...     NaN        2017                   True
# 3   4  IPL-2017     Indore  ...     NaN        2017                   True
# 4   5  IPL-2017  Bangalore  ...     NaN        2017                   True
#
# [5 rows x 20 columns]

# %%
matches_df['won_after_winning_toss'].value_counts().reset_index()
# Out:
#    index  won_after_winning_toss
# 0   True                     393
# 1  False                     363

# %%
plt.figure(figsize=(25,9))
plt.xticks(
    rotation=45, 
    horizontalalignment='right',
    fontweight='light',
    fontsize='x-large'  
)
sns.barplot('index', 'won_after_winning_toss', data=matches_df['won_after_winning_toss'].value_counts().reset_index())
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# ##Observation: Toss winning didn't helped the teams much in winning the match.

# %% [markdown]
# # <ins>Top Stadiums Used</ins>
# Till 2019 total of 756 matches were played. Question now arises is which stadiums were used? and How many games were played in each of these stadiums. Lets exlore!

# %% [markdown]
# ### Firstly, we will create a table using value_counts.

# %%
matches_df['venue'].value_counts().reset_index()
# Out:
#                                                 index  venue
# 0                                        Eden Gardens     77
# 1                               M Chinnaswamy Stadium     73
# 2                                    Wankhede Stadium     73
# 3                                    Feroz Shah Kotla     67
# 4           Rajiv Gandhi International Stadium, Uppal     56
# 5                     MA Chidambaram Stadium, Chepauk     49
# 6                              Sawai Mansingh Stadium     47
# 7          Punjab Cricket Association Stadium, Mohali     35
# 8             Maharashtra Cricket Association Stadium     21
# 9                          Dr DY Patil Sports Academy     17
# 10                         Subrata Roy Sahara Stadium     17
# 11                                          Kingsmead     15
# 12  Punjab Cricket Association IS Bindra Stadium, ...     14
# 13                                    SuperSport Park     12
# ...

# %% [markdown]
# ### Now we will plot the above table in bar graph

# %%
plt.figure(figsize=(25,9))
plt.xticks(
    rotation=45, 
    horizontalalignment='right',
    fontweight='light',
    fontsize='x-large'  
)
sns.barplot('index', 'venue', data=matches_df['venue'].value_counts().reset_index())
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# ##Observation: Eden Gardens is the most used stadium for IPL matches and Till now IPL matches were hosted by 40 venues.

# %% [markdown]
# # <ins>Top Cities in which matches got conducted</ins>

# %%
matches_df['city'].value_counts().reset_index()
# Out:
#              index  city
# 0           Mumbai   101
# 1          Kolkata    77
# 2            Delhi    74
# 3        Bangalore    66
# 4        Hyderabad    64
# 5          Chennai    57
# 6           Jaipur    47
# 7       Chandigarh    46
# 8             Pune    38
# 9           Durban    15
# 10       Bengaluru    14
# 11   Visakhapatnam    13
# 12       Centurion    12
# 13       Ahmedabad    12
# 14          Mohali    10
# 15          Rajkot    10
# 16          Indore     9
# 17      Dharamsala     9
# 18    Johannesburg     8
# 19         Cuttack     7
# 20          Ranchi     7
# 21  Port Elizabeth     7
# 22       Abu Dhabi     7
# 23       Cape Town     7
# 24         Sharjah     6
# 25          Raipur     6
# 26           Kochi     5
# 27          Kanpur     4
# 28          Nagpur     3
# 29     East London     3
# 30       Kimberley     3
# 31    Bloemfontein     2

# %%
plt.figure(figsize=(25,9))
plt.xticks(
    rotation=45, 
    horizontalalignment='right',
    fontweight='light',
    fontsize='x-large'  
)
sns.barplot('index', 'city', data=matches_df['city'].value_counts().reset_index())
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# ## Observation: Maximum number of matches were held in Mumbai

# %% [markdown]
# #<ins>Top Teams which won maximum number of times in all seasons</ins>
# We saw that 756 matches were played. but who won the most?? Let us find out.

# %%
plt.figure(figsize=(25,9))
plt.xticks(
    rotation=45, 
    horizontalalignment='right',
    fontweight='light',
    fontsize='x-large'  
)
sns.barplot('index', 'winner', data=matches_df['winner'].value_counts().reset_index()).set(xlabel="Team", ylabel = "No. of Matches")
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# [Text(0, 0.5, 'No. of Matches'), Text(0.5, 0, 'Team')]

# %% [markdown]
# ##Observation: Mumbai Indians Won most number of matches in this dataset

# %% [markdown]
# # <ins>Which team had maximum number of home matches</ins>

# %%
teamwise_home_away_df.head()
# Out:
#                      team  home_wins  ...  home_win_percentage  away_win_percentage
# 0  Rising Pune Supergiant          5  ...            62.500000            62.500000
# 1          Mumbai Indians         58  ...            57.425743            59.302326
# 2     Chennai Super Kings         51  ...            57.303371            65.333333
# 3          Delhi Capitals          3  ...            50.000000            70.000000
# 4     Sunrisers Hyderabad         30  ...            47.619048            62.222222
#
# [5 rows x 7 columns]

# %%
teamwise_home_away_df.sort_values(by=['home_matches'], ascending=False).reset_index()
# Out:
#     index  ... away_win_percentage
# 0       1  ...           59.302326
# 1       7  ...           51.764706
# 2       2  ...           65.333333
# 3       8  ...           51.578947
# 4       9  ...           61.052632
# 5      10  ...           47.191011
# 6       5  ...           57.500000
# 7       4  ...           62.222222
# 8       6  ...           34.375000
# 9      11  ...           23.076923
# 10     13  ...           75.000000
# 11      0  ...           62.500000
# 12     12  ...           57.142857
# 13      3  ...           70.000000
#
# [14 rows x 8 columns]

# %%
plt.figure(figsize=(25,9))
plt.xticks(
    rotation=45, 
    horizontalalignment='right',
    fontweight='light',
    fontsize='x-large'  
)
sns.barplot('team', 'home_matches', data=teamwise_home_away_df.sort_values(by=['home_matches'], ascending=False).reset_index())
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# ##Observation: Mumbai Indians played most number of home matches

# %% [markdown]
# # <ins>Let's find the batsman who scored max sixes</ins>

# %%
deliveries_df_6 = deliveries_df[deliveries_df['batsman_runs']==6]

# %%
deliveries_df_6 = deliveries_df_6.groupby('batsman').agg({'batsman_runs':sum}).reset_index()

# %%
deliveries_df_6['no. of sixes'] = deliveries_df_6['batsman_runs'].apply(lambda x: x/6)

# %%
deliveries_df_6.head()
# Out:
#           batsman  batsman_runs  no. of sixes
# 0  A Ashish Reddy            90          15.0
# 1     A Choudhary             6           1.0
# 2      A Flintoff            12           2.0
# 3         A Hales            36           6.0
# 4        A Mishra            30           5.0

# %%
deliveries_df_6.sort_values(by=['no. of sixes'], ascending=False, inplace=True)

# %%
plt.figure(figsize=(25,9))
plt.xticks(
    rotation=45, 
    horizontalalignment='right',
    fontweight='light',
    fontsize='x-large'  
)
sns.barplot('batsman', 'no. of sixes', data=deliveries_df_6.head())
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# ##Observation: Chris Gayle has scored most number of sixes.

# %% [markdown]
# # <ins>Let's find the batsman who scored max fours</ins>

# %%
deliveries_df_4 = deliveries_df[deliveries_df['batsman_runs']==4]
deliveries_df_4 = deliveries_df_4.groupby('batsman').agg({'batsman_runs':sum}).reset_index()
deliveries_df_4['no. of fours'] = deliveries_df_4['batsman_runs'].apply(lambda x: x/4)
deliveries_df_4.sort_values(by=['no. of fours'], ascending=False, inplace=True)

# %%
deliveries_df_4.head()
# Out:
#        batsman  batsman_runs  no. of fours
# 317   S Dhawan          2104         526.0
# 343   SK Raina          1980         495.0
# 120  G Gambhir          1968         492.0
# 387    V Kohli          1928         482.0
# 89   DA Warner          1836         459.0

# %%
plt.figure(figsize=(25,9))
plt.xticks(
    rotation=45, 
    horizontalalignment='right',
    fontweight='light',
    fontsize='x-large'  
)
sns.barplot('batsman', 'no. of fours', data=deliveries_df_4.head())
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# ## Observation: Shikhar Dhawan scored maximum number of fours.

# %% [markdown]
# #<ins>Let's find out which player won Player of the match maximum number of times</ins>

# %%
matches_df.head()
# Out:
#    id    Season       city  ... umpire3 Season_year won_after_winning_toss
# 0   1  IPL-2017  Hyderabad  ...     NaN        2017                  False
# 1   2  IPL-2017       Pune  ...     NaN        2017                   True
# 2   3  IPL-2017     Rajkot  ...     NaN        2017                   True
# 3   4  IPL-2017     Indore  ...     NaN        2017                   True
# 4   5  IPL-2017  Bangalore  ...     NaN        2017                   True
#
# [5 rows x 20 columns]

# %%
matches_df['player_of_match'].value_counts().reset_index()
# Out:
#               index  player_of_match
# 0          CH Gayle               21
# 1    AB de Villiers               20
# 2         RG Sharma               17
# 3          MS Dhoni               17
# 4         DA Warner               17
# ..              ...              ...
# 221      GD McGrath                1
# 222       LR Shukla                1
# 223      DL Vettori                1
# 224      EJG Morgan                1
# 225         SB Wagh                1
#
# [226 rows x 2 columns]

# %%
plt.figure(figsize=(15,9))
plt.xticks(
    rotation=45, 
    horizontalalignment='right',
    fontweight='light',
    fontsize='x-large'  
)
sns.barplot('index', 'player_of_match', data=matches_df['player_of_match'].value_counts().reset_index().head(15))
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# ##Observation: Chris Gayle won Player of the match maximum number of times followed by AB de Villiers

# %% [markdown]
# #<ins>Let's find out which team won the toss maximum times.</ins>

# %%
matches_df['toss_winner'].value_counts().reset_index()
# Out:
#                           index  toss_winner
# 0                Mumbai Indians           98
# 1         Kolkata Knight Riders           92
# 2           Chennai Super Kings           89
# 3   Royal Challengers Bangalore           81
# 4               Kings XI Punjab           81
# 5              Delhi Daredevils           80
# 6              Rajasthan Royals           80
# 7           Sunrisers Hyderabad           46
# 8               Deccan Chargers           43
# 9                 Pune Warriors           20
# 10                Gujarat Lions           15
# 11               Delhi Capitals           10
# 12         Kochi Tuskers Kerala            8
# 13      Rising Pune Supergiants            7
# 14       Rising Pune Supergiant            6

# %%
plt.figure(figsize=(25,9))
plt.xticks(
    rotation=45, 
    horizontalalignment='right',
    fontweight='light',
    fontsize='x-large'  
)
sns.barplot('index', 'toss_winner', data=matches_df['toss_winner'].value_counts().reset_index().head())
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# ##Observation: Mumbai Indians won the toss maximum times.

# %% [markdown]
# # <ins>Venue , Team and Win relation</ins>
# We know who won. We know which stadiums were used. I feel you are thinking if there is any realtion between the winners and the venues. Lets try to understand this.

# %%
venue_winner_df = matches_df[['venue','winner']]
venue_winner_df.head()
# Out:
#                                        venue                       winner
# 0  Rajiv Gandhi International Stadium, Uppal          Sunrisers Hyderabad
# 1    Maharashtra Cricket Association Stadium       Rising Pune Supergiant
# 2     Saurashtra Cricket Association Stadium        Kolkata Knight Riders
# 3                     Holkar Cricket Stadium              Kings XI Punjab
# 4                      M Chinnaswamy Stadium  Royal Challengers Bangalore

# %%
# creating a data frame that has counts of countries and players
venue_and_win = pd.DataFrame(venue_winner_df.value_counts()) # taking values and converting to df
venue_and_win = venue_and_win.reset_index() # resetting the index
venue_and_win.columns = ['Venue', 'match_winner','no_of_times'] # renaming columns
top_ten_city_winner = venue_and_win.head(10)
top_ten_city_winner
# Out:
#                                         Venue  ... no_of_times
# 0                                Eden Gardens  ...          45
# 1                            Wankhede Stadium  ...          42
# 2             MA Chidambaram Stadium, Chepauk  ...          34
# 3                       M Chinnaswamy Stadium  ...          34
# 4                      Sawai Mansingh Stadium  ...          32
# 5                            Feroz Shah Kotla  ...          27
# 6   Rajiv Gandhi International Stadium, Uppal  ...          25
# 7  Punjab Cricket Association Stadium, Mohali  ...          18
# 8                                Eden Gardens  ...          10
# 9                       M Chinnaswamy Stadium  ...           8
#
# [10 rows x 3 columns]

# %%
plt.figure(figsize=(25,10)) # setting size of plot
plt.title('top 10 winners and their relation with venues')
ax = sns.barplot(x="match_winner", y='no_of_times',hue="Venue", data = top_ten_city_winner)
plt.xticks(rotation=45, 
    horizontalalignment='right',
    fontweight='light',
    fontsize='x-large' )
# Out:
# (array([0, 1, 2, 3, 4, 5, 6, 7]), <a list of 8 Text major ticklabel objects>)

# %% [markdown]
# ##Observation: Mumbai seems to be only team in top 10 to have won at 3 different stadiums .
#
# ##KKR on the other hand seems to  have won in their own home ground the most.

# %% [markdown]
# # <ins>Top 3 Teams performance report in every season </ins>

# %%
matches_df.head()
# Out:
#    id    Season       city  ... umpire3 Season_year won_after_winning_toss
# 0   1  IPL-2017  Hyderabad  ...     NaN        2017                  False
# 1   2  IPL-2017       Pune  ...     NaN        2017                   True
# 2   3  IPL-2017     Rajkot  ...     NaN        2017                   True
# 3   4  IPL-2017     Indore  ...     NaN        2017                   True
# 4   5  IPL-2017  Bangalore  ...     NaN        2017                   True
#
# [5 rows x 20 columns]

# %%
matches_df['winner'].value_counts()
# Out:
# Mumbai Indians                 109
# Chennai Super Kings            100
# Kolkata Knight Riders           92
# Royal Challengers Bangalore     84
# Kings XI Punjab                 82
# Rajasthan Royals                75
# Delhi Daredevils                67
# Sunrisers Hyderabad             58
# Deccan Chargers                 29
# Gujarat Lions                   13
# Pune Warriors                   12
# Delhi Capitals                  10
# Rising Pune Supergiant          10
# Kochi Tuskers Kerala             6
# Rising Pune Supergiants          5
# Name: winner, dtype: int64

# %% [markdown]
# ###Let's get rid of null values from winner column

# %%
matches_df = matches_df[~matches_df['winner'].isna()]

# %%
matches_df_win = matches_df[(matches_df['winner']=='Mumbai Indians')  | (matches_df['winner']=='Chennai Super Kings') | (matches_df['winner']=='Kolkata Knight Riders') ]

# %%
matches_df_win_1 = matches_df_win.groupby('Season_year').agg({'winner':Counter}).reset_index()

# %%
matches_df_win_1.head()
# Out:
#   Season_year                                             winner
# 0        2008  {'Kolkata Knight Riders': 6, 'Chennai Super Ki...
# 1        2009  {'Mumbai Indians': 5, 'Chennai Super Kings': 8...
# 2        2010  {'Kolkata Knight Riders': 7, 'Mumbai Indians':...
# 3        2011  {'Chennai Super Kings': 11, 'Mumbai Indians': ...
# 4        2012  {'Mumbai Indians': 10, 'Chennai Super Kings': ...

# %%
matches_df_win_1['winner'][0]
# Out:
# Counter({'Chennai Super Kings': 9,
#          'Kolkata Knight Riders': 6,
#          'Mumbai Indians': 7})

# %%
matches_df_win_2 = matches_df_win_1.join(pd.json_normalize(matches_df_win_1['winner']))

# %%
matches_df_win_2.head()
# Out:
#   Season_year  ... Mumbai Indians
# 0        2008  ...              7
# 1        2009  ...              5
# 2        2010  ...             11
# 3        2011  ...             10
# 4        2012  ...             10
#
# [5 rows x 5 columns]

# %%
del matches_df_win_2['winner']

# %%
# sns.factorplot(x="Season_year", y=["Kolkata Knight Riders", "Mumbai Indians", "Chennai Super Kings"], data=matches_df_win_2)
matches_df_win_2.plot(x='Season_year', y=["Kolkata Knight Riders", "Mumbai Indians", "Chennai Super Kings"], figsize=(20,9), grid=True)

# %%
matches_df_win_2.plot(x='Season_year', y=["Kolkata Knight Riders", "Mumbai Indians", "Chennai Super Kings"], figsize=(20,9), grid=True, kind='bar')

# %% [markdown]
# ##Observation: Chennai Super Kings and Mumbai Indians has a head to head comparision. But due to the ban, CSK is not in 2016 & 2017

# %% [markdown]
# #<ins> What is the most common way of dismissal??</ins>

# %%
deliveries_df['dismissal_kind'].value_counts().reset_index()
# Out:
#                    index  dismissal_kind
# 0                 caught            5348
# 1                 bowled            1581
# 2                run out             852
# 3                    lbw             540
# 4                stumped             278
# 5      caught and bowled             211
# 6           retired hurt              12
# 7             hit wicket              10
# 8  obstructing the field               2

# %%
# plot = most_way_out_df.plot.pie(y='no_of_times', figsize=(5, 5))
plt.figure(figsize=(10,10)) # setting size of plot
plt.title('counts of ways of dismissal')
ax = sns.barplot(x="index",y="dismissal_kind",data=deliveries_df['dismissal_kind'].value_counts().reset_index())

# %% [markdown]
# ##Observation: Whopping 60% people get out by being caught followed by getting bowled.

# %% [markdown]
# #<ins> Dismissal records of players who scored maximum runs</ins>

# %%
d1 = deliveries_df.groupby('player_dismissed').agg({'dismissal_kind':Counter}).reset_index()
d2 = d1.join(pd.json_normalize(d1['dismissal_kind']))

# %%
d3 = d2[(d2['player_dismissed']=='V Kohli') | (d2['player_dismissed']=='SK Raina') | (d2['player_dismissed']=='RG Sharma') | (d2['player_dismissed']=='DA Warner') | (d2['player_dismissed']=='S Dhawan') | (d2['player_dismissed']=='CH Gayle') | (d2['player_dismissed']=='MS Dhoni')]

# %%
d3.plot(x='player_dismissed', y=["caught", "bowled", "run out", "lbw", "stumped", "caught and bowled", "retired hurt", "hit wicket"], figsize=(25,9), grid=True, kind='bar')

# %% [markdown]
# ## Observation: Maximum players got dismissed by catch out.

# %% [markdown]
# #<ins>Conclusions</ins>
#
#
# *   Chris Gayle is the most valuable player in IPL
# *   Mumbai Indians is the most successful team in IPL followed by Chennai Super Kings
# *   Toss Winning does not help much with match winning.
# *   Maximum number of IPL matches were held in Eden Gardens
# *   Mumbai Indians won the toss maximum times.
# *   Shikhar Dhawan scored maximum fours (526 Fours).
# *   Chris Gayle scored maximum sixes (327 Sixes).
# *   Mumbai Indians played maximum number of matches in Mumbai.
# *   Maximum number of IPL matches were held in 2013 (76 matches).
